# %%
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv("../data/poems.csv")
df.head()
# Out:
#    sonnet_number                                              title  \
# 0              1          From Fairest Creatures We Desire Increase
# 1              2          When Forty Winters Shall Besiege Thy Brow
# 2              3  Look In Thy Glass, And Tell The Face Thou Viewest
# 3              4          Unthrifty Loveliness, Why Dost Thou Spend
# 4              5       Those Hours, That With Gentle Work Did Frame
#
#                                                 text  \
# 0  From fairest creatures we desire increase,\nTh...
# 1  When forty winters shall besiege thy brow,\nAn...
# 2  Look in thy glass, and tell the face thou view...
# 3  Unthrifty loveliness, why dost thou spend\nUpo...
# 4  Those hours, that with gentle work did frame\n...
#
#                                                theme   label
# 0  Beauty should reproduce itself before time and...  beauty
# 1  Aging empties outward beauty unless it is rene...    time
# 2  Self-love becomes selfishness if it refuses to...  beauty
# 3  Beauty is a gift meant to be passed on, not ho...  beauty
# 4  Time destroys beauty, but some essence can sur...    time

# %%
print(df[["sonnet_number", "title", "label"]])
print()
print(df["label"].value_counts())
# Out:
#     sonnet_number                                              title  \
# 0               1          From Fairest Creatures We Desire Increase
# 1               2          When Forty Winters Shall Besiege Thy Brow
# 2               3  Look In Thy Glass, And Tell The Face Thou Viewest
# 3               4          Unthrifty Loveliness, Why Dost Thou Spend
# 4               5       Those Hours, That With Gentle Work Did Frame
# 5               6           Then Let Not Winter’s Ragged Hand Deface
# 6               7          Lo! In The Orient When The Gracious Light
# 7               8       Music To Hear, Why Hear’st Thou Music Sadly?
# 8               9                Is It For Fear To Wet A Widow’s Eye
# 9              10       For Shame Deny That Thou Bear’st Love To Any
# 10             11   As Fast As Thou Shalt Wane, So Fast Thou Grow’st
# 11             12      When I Do Count The Clock That Tells The Time
# 12             13      O, That You Were Yourself! But, Love, You Are
# 13             14         Not From The Stars Do I My Judgement Pluck
# 14             15             When I Consider Every Thing That Grows
# 15             16            But Wherefore Do Not You A Mightier Way
# 16             17       Who Will Believe In My Verse In Time To Come
# 17             18            Shall I Compare Thee To A Summer’s Day?
# 18             19          Devouring Time, Blunt Thou The Lion’s Paw
# 19             20      A Woman’s Face With Nature’s Own Hand Painted
#
#         label
# 0      beauty
# 1        time
# 2      beauty
# 3      beauty
# 4        time
# 5        time
# 6        time
# 7        love
# 8        love
# 9        love
# 10       time
# 11  mortality
# 12       love
# 13     beauty
# 14       time
# 15       time
# 16     beauty
# 17     beauty
# 18       time
# 19     beauty
#
# label
# time         8
# beauty       7
# love         4
# mortality    1
# Name: count, dtype: int64

# %%
X = df["text"]
y = df["label"]

# %%
model = Pipeline([
    ("tfidf", TfidfVectorizer(lowercase=True, stop_words="english")),
    ("clf", LogisticRegression(max_iter=1000))
])

# %%
model.fit(X, y)
print("Model trained.")
# Out:
# Model trained.

# %%
predictions = model.predict(X)

for title, true_label, pred_label in zip(df["title"], y, predictions):
    print(title)
    print("  True:", true_label)
    print("  Pred:", pred_label)
    print()
# Out:
# From Fairest Creatures We Desire Increase
#   True: beauty
#   Pred: beauty
#
# When Forty Winters Shall Besiege Thy Brow
#   True: time
#   Pred: time
#
# Look In Thy Glass, And Tell The Face Thou Viewest
#   True: beauty
#   Pred: beauty
#
# Unthrifty Loveliness, Why Dost Thou Spend
#   True: beauty
#   Pred: beauty
#
# Those Hours, That With Gentle Work Did Frame
#   True: time
#   Pred: time
#
# Then Let Not Winter’s Ragged Hand Deface
#   True: time
#   Pred: time
#
# Lo! In The Orient When The Gracious Light
#   True: time
#   Pred: time
#
# Music To Hear, Why Hear’st Thou Music Sadly?
#   True: love
#   Pred: love
#
# Is It For Fear To Wet A Widow’s Eye
#   True: love
#   Pred: love
#
# For Shame Deny That Thou Bear’st Love To Any
#   True: love
#   Pred: love
#
# As Fast As Thou Shalt Wane, So Fast Thou Grow’st
#   True: time
#   Pred: time
#
# When I Do Count The Clock That Tells The Time
#   True: mortality
#   Pred: time
#
# O, That You Were Yourself! But, Love, You Are
#   True: love
#   Pred: love
#
# Not From The Stars Do I My Judgement Pluck
#   True: beauty
#   Pred: beauty
#
# When I Consider Every Thing That Grows
#   True: time
#   Pred: time
#
# But Wherefore Do Not You A Mightier Way
#   True: time
#   Pred: time
#
# Who Will Believe In My Verse In Time To Come
#   True: beauty
#   Pred: beauty
#
# Shall I Compare Thee To A Summer’s Day?
#   True: beauty
#   Pred: beauty
#
# Devouring Time, Blunt Thou The Lion’s Paw
#   True: time
#   Pred: time
#
# A Woman’s Face With Nature’s Own Hand Painted
#   True: beauty
#   Pred: beauty

# %%
sample_poem = """
Love looks not with the eyes, but with the mind,
And therefore is winged Cupid painted blind.
"""

prediction = model.predict([sample_poem])[0]
print("Predicted label:", prediction)
# Out:
# Predicted label: time
